# %% [markdown]
# # HOUSE PRICING INDIA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('House Price India.csv')

# %%
df.head()
# Out:
#            id   Date  No of bedrooms  No of bathrooms  living area  lot area  \
# 0  6762810635  42491               4             2.50         2920      4000
# 1  6762810998  42491               5             2.75         2910      9480
# 2  6762812605  42491               4             2.50         3310     42998
# 3  6762812919  42491               3             2.00         2710      4500
# 4  6762813105  42491               3             2.50         2600      4750
#
#    No of floors  waterfront present  No of views  house condition  ...  \
# 0           1.5                   0            0                5  ...
# 1           1.5                   0            0                3  ...
# 2           2.0                   0            0                3  ...
# 3           1.5                   0            0                4  ...
# 4           1.0                   0            0                4  ...
#
#    Built Year  Renovation Year  Postal Code  Lattitude  Longitude  \
# ...

# %%
df.describe()
# Out:
#                  id          Date  No of bedrooms  No of bathrooms  \
# count  1.461900e+04  14619.000000    14619.000000     14619.000000
# mean   6.762821e+09  42604.546412        3.379233         2.129557
# std    6.237162e+03     67.343747        0.938655         0.769955
# min    6.762810e+09  42491.000000        1.000000         0.500000
# 25%    6.762815e+09  42546.000000        3.000000         1.750000
# 50%    6.762821e+09  42600.000000        3.000000         2.250000
# 75%    6.762826e+09  42662.000000        4.000000         2.500000
# max    6.762832e+09  42734.000000       33.000000         8.000000
#
#         living area      lot area  No of floors  waterfront present  \
# count  14619.000000  1.461900e+04  14619.000000        14619.000000
# mean    2098.156851  1.509369e+04      1.502326            0.007661
# std      928.218740  3.792089e+04      0.540241            0.087196
# min      370.000000  5.200000e+02      1.000000            0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14619 entries, 0 to 14618
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14619 non-null  int64
#  1   Date                            14619 non-null  int64
#  2   No of bedrooms                  14619 non-null  int64
#  3   No of bathrooms                 14619 non-null  float64
#  4   living area                     14619 non-null  int64
#  5   lot area                        14619 non-null  int64
#  6   No of floors                    14619 non-null  float64
#  7   waterfront present              14619 non-null  int64
#  8   No of views                     14619 non-null  int64
#  9   house condition                 14619 non-null  int64
#  10  house grade                     14619 non-null  int64
#  11  house area(excluding basement)  14619 non-null  int64
# ...

# %% [markdown]
# # EDA

# %%
plt.rcParams['figure.figsize'] = (12, 8)

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
df.corr()['Price'].sort_values()
# Out:
# id                               -0.773268
# Postal Code                      -0.115477
# Date                             -0.027367
# Distance from the airport         0.004074
# No of schools nearby              0.009904
# Longitude                         0.024807
# house condition                   0.040609
# Built Year                        0.050936
# lot_area_renov                    0.075697
# lot area                          0.082117
# Renovation Year                   0.133362
# No of floors                      0.262649
# waterfront present                0.263943
# Lattitude                         0.297570
# No of bedrooms                    0.308165
# Area of the basement              0.330499
# No of views                       0.394954
# No of bathrooms                   0.532031
# living_area_renov                 0.585021
# house area(excluding basement)    0.615179
# house grade                       0.671805
# living area                       0.712276
# ...

# %%
sns.distplot(df['Price'])
# Out:
# /tmp/ipykernel_17572/834922981.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.scatterplot(df,x='living area',y='Price')
# Out:
# <Axes: xlabel='living area', ylabel='Price'>

# %%
sns.countplot(df,x='house grade')
# Out:
# <Axes: xlabel='house grade', ylabel='count'>

# %%
sns.scatterplot(df,x='house area(excluding basement)',y='Price')
# Out:
# <Axes: xlabel='house area(excluding basement)', ylabel='Price'>

# %%
sns.scatterplot(df,x='house area(excluding basement)',y='living area')
# Out:
# <Axes: xlabel='house area(excluding basement)', ylabel='living area'>

# %%
sns.countplot(df,x='No of bathrooms')
# Out:
# <Axes: xlabel='No of bathrooms', ylabel='count'>

# %%
sns.countplot(df,x='No of floors')
# Out:
# <Axes: xlabel='No of floors', ylabel='count'>

# %%
sns.countplot(df,x='No of bedrooms')
# Out:
# <Axes: xlabel='No of bedrooms', ylabel='count'>

# %%
df['No of floors'] = df['No of floors'].apply(lambda x : round(x))

# %%
df['No of bathrooms'] = df['No of bathrooms'].apply(lambda x : round(x))

# %%
sns.pointplot(df,x = 'No of bathrooms',y='No of bedrooms')
# Out:
# <Axes: xlabel='No of bathrooms', ylabel='No of bedrooms'>

# %%
df['Lattitude']
# Out:
# 0        52.8878
# 1        52.8852
# 2        52.9532
# 3        52.9047
# 4        52.9133
#           ...
# 14614    52.6191
# 14615    52.5075
# 14616    52.7289
# 14617    52.7157
# 14618    52.5338
# Name: Lattitude, Length: 14619, dtype: float64

# %%
df['Longitude']
# Out:
# 0       -114.470
# 1       -114.468
# 2       -114.321
# 3       -114.485
# 4       -114.590
#           ...
# 14614   -114.472
# 14615   -114.393
# 14616   -114.507
# 14617   -114.411
# 14618   -114.552
# Name: Longitude, Length: 14619, dtype: float64

# %%
sns.scatterplot(x='Longitude', y='Lattitude', hue='Price', data=df, palette='viridis')
# Out:
# <Axes: xlabel='Longitude', ylabel='Lattitude'>

# %%
sns.countplot(df,x='No of views')
# Out:
# <Axes: xlabel='No of views', ylabel='count'>

# %%
sns.boxplot(df,x='house grade',y = 'Price')
# Out:
# <Axes: xlabel='house grade', ylabel='Price'>

# %% [markdown]
# # feature extraction

# %%
df.head()
# Out:
#            id   Date  No of bedrooms  No of bathrooms  living area  lot area  \
# 0  6762810635  42491               4                2         2920      4000
# 1  6762810998  42491               5                3         2910      9480
# 2  6762812605  42491               4                2         3310     42998
# 3  6762812919  42491               3                2         2710      4500
# 4  6762813105  42491               3                2         2600      4750
#
#    No of floors  waterfront present  No of views  house condition  ...  \
# 0             2                   0            0                5  ...
# 1             2                   0            0                3  ...
# 2             2                   0            0                3  ...
# 3             2                   0            0                4  ...
# 4             1                   0            0                4  ...
#
#    Built Year  Renovation Year  Postal Code  Lattitude  Longitude  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14619 entries, 0 to 14618
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14619 non-null  int64
#  1   Date                            14619 non-null  int64
#  2   No of bedrooms                  14619 non-null  int64
#  3   No of bathrooms                 14619 non-null  int64
#  4   living area                     14619 non-null  int64
#  5   lot area                        14619 non-null  int64
#  6   No of floors                    14619 non-null  int64
#  7   waterfront present              14619 non-null  int64
#  8   No of views                     14619 non-null  int64
#  9   house condition                 14619 non-null  int64
#  10  house grade                     14619 non-null  int64
#  11  house area(excluding basement)  14619 non-null  int64
# ...

# %%
df = df.drop(['Postal Code'],axis = 1)

# %%
df = df.drop(['No of views'],axis = 1)

# %%
df = df.drop(['Renovation Year'],axis = 1)

# %%
df = df.drop(['id'],axis = 1)

# %%
df = df.drop(['waterfront present'],axis = 1)

# %%
df = df[df['No of bedrooms'] != 33]

# %% [markdown]
# # train test split

# %%
X = df.drop('Price',axis = 1)

# %%
y = df['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train= scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (9794, 17)

# %%
X_test.shape
# Out:
# (4824, 17)

# %% [markdown]
# # Creating a model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import Adam
# Out:
# 2024-08-29 15:07:01.545652: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-29 15:07:01.550102: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-29 15:07:01.748494: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-29 15:07:02.499115: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
model = Sequential()

model.add(Dense(18,activation='relu'))

model.add(Dense(18,activation='relu'))

model.add(Dense(18,activation='relu'))


model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train.values,
          validation_data=(X_test,y_test.values),
          batch_size=128,epochs=800, callbacks=[early_stopping] )
# Out:
# Epoch 1/800
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 426060644352.0000 - val_loss: 425622405120.0000
# Epoch 2/800
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 409624051712.0000 - val_loss: 425601728512.0000
# Epoch 3/800
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 421814796288.0000 - val_loss: 425450831872.0000
# Epoch 4/800
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 434101125120.0000 - val_loss: 424915533824.0000
# Epoch 5/800
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 441136513024.0000 - val_loss: 423601766400.0000
# Epoch 6/800
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 421983027200.0000 - val_loss: 420985241600.0000
# Epoch 7/800
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 413127049216.0000 - val_loss: 416524107776.0000
# Epoch 8/800
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 426083254272.0000 - val_loss: 409650102272.0000
# Epoch 9/800
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 393713942528.0000 - val_loss: 399785689088.0000
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <Axes: >

# %% [markdown]
# # Predicting a house prize

# %%
single_house = df.drop('Price',axis=1).iloc[8]

# %%
single_house = scaler.transform(single_house.values.reshape(-1, 17))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
single_house
# Out:
# array([[0.        , 0.3       , 0.25      , 0.13829787, 0.01080558,
#         0.5       , 1.        , 0.33333333, 0.10188261, 0.18672199,
#         0.17391304, 0.84942585, 0.26166667, 0.32882012, 0.01814932,
#         0.5       , 0.1       ]])

# %%
model.predict(single_house)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# array([[641027.56]], dtype=float32)

# %%
df.iloc[8]
# Out:
# Date                               42491.0000
# No of bedrooms                         4.0000
# No of bathrooms                        2.0000
# living area                         2200.0000
# lot area                           11250.0000
# No of floors                           2.0000
# house condition                        5.0000
# house grade                            7.0000
# house area(excluding basement)      1300.0000
# Area of the basement                 900.0000
# Built Year                          1920.0000
# Lattitude                             52.9145
# Longitude                           -114.3910
# living_area_renov                   2320.0000
# lot_area_renov                     10814.0000
# No of schools nearby                   2.0000
# Distance from the airport             53.0000
# Price                             698000.0000
# Name: 8, dtype: float64

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = rf_model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'Mean Absolute Error: {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'R-squared (R²): {r2}')
# Out:
# Mean Absolute Error: 74103.21676616915
# Mean Squared Error (MSE): 21144955658.070255
# R-squared (R²): 0.8443275334959173

# %% [markdown]
# # XGboost Regression

# %%
from xgboost import XGBRegressor

# %%
xgb_regressor = XGBRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
xgb_regressor.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
y_pred = xgb_regressor.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'R-squared (R²): {r2}')
# Out:
# Mean Absolute Error (MAE): 72955.72055251089
# Mean Squared Error (MSE): 22687576980.598145
# R-squared (R²): 0.8329704999923706

# %%
import joblib

# %%
joblib.dump(scaler, "scl2.h5")
# Out:
# ['scl2.h5']

# %%
joblib.dump(xgb_regressor, "xgb.pkl")
# Out:
# ['xgb.pkl']

# %%
df.columns
# Out:
# Index(['Date', 'No of bedrooms', 'No of bathrooms', 'living area', 'lot area',
#        'No of floors', 'house condition', 'house grade',
#        'house area(excluding basement)', 'Area of the basement', 'Built Year',
#        'Lattitude', 'Longitude', 'living_area_renov', 'lot_area_renov',
#        'No of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')
